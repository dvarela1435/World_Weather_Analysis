# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vostok
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | srednekolymsk
# Processing Record 5 of Set 1 | lagoa
# Processing Record 6 of Set 1 | hachinohe
# Processing Record 7 of Set 1 | touros
# Processing Record 8 of Set 1 | pacific grove
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | sorland
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | lipari
# Processing Record 13 of Set 1 | vyazemskiy
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | baykit
# Processing Record 16 of Set 1 | ponta do sol
# Processing Record 17 of Set 1 | puerto cabezas
# Processing Record 18 of Set 1 | gua musang
# Processing Record 19 of Set 1 | yenangyaung
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | norman wells
# Processing Record 22 of Set 1 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 1 | kununurra
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | schmalkalden
# Processing Record 26 of Set 1 | cherskiy
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | chokurdakh
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | dasoguz
# Processing Record 32 of Set 1 | diffa
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | maldonado
# Processing Record 36 of Set 1 | maamba
# Processing Record 37 of Set 1 | severo-kurilsk
# Processing Record 38 of Set 1 | iskateley
# Processing Record 39 of Set 1 | vila velha
# Processing Record 40 of Set 1 | saint anthony
# Processing Record 41 of Set 1 | shimoda
# Processing Record 42 of Set 1 | san patricio
# Processing Record 43 of Set 1 | yeppoon
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | cockburn town
# Processing Record 46 of Set 1 | klamath falls
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | smithers
# Processing Record 49 of Set 1 | wucheng
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | kenai
# Processing Record 2 of Set 2 | saint-georges
# Processing Record 3 of Set 2 | nome
# Processing Record 4 of Set 2 | coihaique
# Processing Record 5 of Set 2 | ternate
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | broome
# Processing Record 8 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 2 | jiaozhou
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | port hedland
# Processing Record 12 of Set 2 | salalah
# Processing Record 13 of Set 2 | ushuaia
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | leningradskiy
# Processing Record 18 of Set 2 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 2 | solnechnyy
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | ngawi
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | rocha
# Processing Record 25 of Set 2 | tasiilaq
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | laguna
# Processing Record 29 of Set 2 | hami
# Processing Record 30 of Set 2 | husavik
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | kargat
# Processing Record 35 of Set 2 | vao
# Processing Record 36 of Set 2 | dhidhdhoo
# Processing Record 37 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | kaeo
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | viedma
# Processing Record 43 of Set 2 | solwezi
# Processing Record 44 of Set 2 | bahia blanca
# Processing Record 45 of Set 2 | soe
# Processing Record 46 of Set 2 | hofn
# Processing Record 47 of Set 2 | dingle
# Processing Record 48 of Set 2 | kulhudhuffushi
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | mnogovershinnyy
# Processing Record 1 of Set 3 | port hardy
# Processing Record 2 of Set 3 | ostrovnoy
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | mbandaka
# Processing Record 5 of Set 3 | fort nelson
# Processing Record 6 of Set 3 | pemangkat
# Processing Record 7 of Set 3 | houma
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | homer
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | marzuq
# Processing Record 12 of Set 3 | hasaki
# Processing Record 13 of Set 3 | dolinsk
# Processing Record 14 of Set 3 | kapaa
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | mahishadal
# Processing Record 17 of Set 3 | bandarbeyla
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | bezenchuk
# Processing Record 20 of Set 3 | bambous virieux
# Processing Record 21 of Set 3 | axim
# Processing Record 22 of Set 3 | mayor pablo lagerenza
# Processing Record 23 of Set 3 | tessalit
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | podosinovets
# Processing Record 26 of Set 3 | dandong
# Processing Record 27 of Set 3 | yumen
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | vaini
# Processing Record 30 of Set 3 | ahipara
# Processing Record 31 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 3 | nioro
# Processing Record 33 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | cidreira
# Processing Record 36 of Set 3 | saint-philippe
# Processing Record 37 of Set 3 | visnes
# Processing Record 38 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 3 | moses lake
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | basco
# Processing Record 42 of Set 3 | goderich
# Processing Record 43 of Set 3 | norfolk
# Processing Record 44 of Set 3 | east london
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | viloco
# Processing Record 47 of Set 3 | olinda
# Processing Record 48 of Set 3 | saldanha
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 50 of Set 3 | kodiak
# Processing Record 1 of Set 4 | ambilobe
# Processing Record 2 of Set 4 | evensk
# Processing Record 3 of Set 4 | la baule-escoublac
# Processing Record 4 of Set 4 | eureka
# Processing Record 5 of Set 4 | sept-iles
# Processing Record 6 of Set 4 | sitka
# Processing Record 7 of Set 4 | cabedelo
# Processing Record 8 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 4 | dzilam gonzalez
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 4 | rio grande
# Processing Record 13 of Set 4 | lima
# Processing Record 14 of Set 4 | itarema
# Processing Record 15 of Set 4 | valdivia
# Processing Record 16 of Set 4 | rapar
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | libreville
# Processing Record 19 of Set 4 | shimanovsk
# Processing Record 20 of Set 4 | hilo
# Processing Record 21 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | adelaide
# Processing Record 23 of Set 4 | lahij
# Processing Record 24 of Set 4 | sawtell
# Processing Record 25 of Set 4 | khatanga
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | wabrzezno
# Processing Record 28 of Set 4 | esperance
# Processing Record 29 of Set 4 | rayong
# Processing Record 30 of Set 4 | omboue
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | locri
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | avera
# Processing Record 35 of Set 4 | vanimo
# Processing Record 36 of Set 4 | umm lajj
# Processing Record 37 of Set 4 | wattegama
# Processing Record 38 of Set 4 | cabinda
# Processing Record 39 of Set 4 | tiksi
# Processing Record 40 of Set 4 | richards bay
# Processing Record 41 of Set 4 | biak
# Processing Record 42 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 4 | pucallpa
# Processing Record 44 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 4 | sembe
# Processing Record 46 of Set 4 | coahuayana
# Processing Record 47 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 4 | chapais
# Processing Record 49 of Set 4 | hithadhoo
# Processing Record 50 of Set 4 | ballina
# Processing Record 1 of Set 5 | birigui
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | kaitangata
# Processing Record 4 of Set 5 | gizo
# Processing Record 5 of Set 5 | nikolskoye
# Processing Record 6 of Set 5 | urumqi
# Processing Record 7 of Set 5 | erzin
# Processing Record 8 of Set 5 | mamakan
# Processing Record 9 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | astara
# Processing Record 11 of Set 5 | requena
# Processing Record 12 of Set 5 | haines junction
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | festus
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | purificacion
# Processing Record 17 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 18 of Set 5 | maniitsoq
# Processing Record 19 of Set 5 | san jose del guaviare
# Processing Record 20 of Set 5 | guarda
# Processing Record 21 of Set 5 | portel
# Processing Record 22 of Set 5 | el alto
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | bathsheba
# Processing Record 25 of Set 5 | marfino
# Processing Record 26 of Set 5 | payo
# Processing Record 27 of Set 5 | finale ligure
# Processing Record 28 of Set 5 | puerto penasco
# Processing Record 29 of Set 5 | san cristobal
# Processing Record 30 of Set 5 | coquimbo
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | ixtapa
# Processing Record 33 of Set 5 | asau
# Processing Record 34 of Set 5 | colares
# Processing Record 35 of Set 5 | bayan
# Processing Record 36 of Set 5 | iglesias
# Processing Record 37 of Set 5 | clarksburg
# Processing Record 38 of Set 5 | san angelo
# Processing Record 39 of Set 5 | mounana
# Processing Record 40 of Set 5 | gbarnga
# Processing Record 41 of Set 5 | butaritari
# Processing Record 42 of Set 5 | sobolevo
# Processing Record 43 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 5 | iznoski
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | talnakh
# Processing Record 47 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 5 | polovinnoye
# Processing Record 49 of Set 5 | coromandel
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | aberystwyth
# Processing Record 2 of Set 6 | prince rupert
# Processing Record 3 of Set 6 | cuamba
# Processing Record 4 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 6 | suchitlan
# Processing Record 6 of Set 6 | kenora
# Processing Record 7 of Set 6 | kanniyakumari
# Processing Record 8 of Set 6 | isangel
# Processing Record 9 of Set 6 | los llanos de aridane
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | vardo
# Processing Record 12 of Set 6 | seydi
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | huejuquilla el alto
# Processing Record 15 of Set 6 | namatanai
# Processing Record 16 of Set 6 | constitucion
# Processing Record 17 of Set 6 | marsa matruh
# Processing Record 18 of Set 6 | sohbatpur
# Processing Record 19 of Set 6 | lebu
# Processing Record 20 of Set 6 | toba
# Processing Record 21 of Set 6 | barcelos
# Processing Record 22 of Set 6 | ploemeur
# Processing Record 23 of Set 6 | makakilo city
# Processing Record 24 of Set 6 | anchorage
# Processing Record 25 of Set 6 | saint george
# Processing Record 26 of Set 6 | kidal
# Processing Record 27 of Set 6 | osakarovka
# Processing Record 28 of Set 6 | vuktyl
# Processing Record 29 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 6 | meulaboh
# Processing Record 31 of Set 6 | tura
# Processing Record 32 of Set 6 | choucheng
# City not found. Skipping...
# Processing Record 33 of Set 6 | zhicheng
# Processing Record 34 of Set 6 | atbasar
# Processing Record 35 of Set 6 | serenje
# Processing Record 36 of Set 6 | ulundi
# Processing Record 37 of Set 6 | fatezh
# Processing Record 38 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 39 of Set 6 | ziro
# Processing Record 40 of Set 6 | jalu
# Processing Record 41 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 42 of Set 6 | amazar
# Processing Record 43 of Set 6 | kamina
# Processing Record 44 of Set 6 | faanui
# Processing Record 45 of Set 6 | ipameri
# Processing Record 46 of Set 6 | flin flon
# Processing Record 47 of Set 6 | devils lake
# Processing Record 48 of Set 6 | clyde river
# Processing Record 49 of Set 6 | aksu
# Processing Record 50 of Set 6 | vila franca do campo
# Processing Record 1 of Set 7 | mbini
# Processing Record 2 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 7 | kilindoni
# Processing Record 4 of Set 7 | portland
# Processing Record 5 of Set 7 | warrington
# Processing Record 6 of Set 7 | xining
# Processing Record 7 of Set 7 | taitung
# Processing Record 8 of Set 7 | skjervoy
# Processing Record 9 of Set 7 | kota kinabalu
# Processing Record 10 of Set 7 | lasa
# Processing Record 11 of Set 7 | kalabo
# Processing Record 12 of Set 7 | ust-tsilma
# Processing Record 13 of Set 7 | maku
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | praya
# Processing Record 16 of Set 7 | grindavik
# Processing Record 17 of Set 7 | santa cruz
# Processing Record 18 of Set 7 | chara
# Processing Record 19 of Set 7 | high level
# Processing Record 20 of Set 7 | ratanpur
# Processing Record 21 of Set 7 | granville
# Processing Record 22 of Set 7 | leshukonskoye
# Processing Record 23 of Set 7 | olafsvik
# Processing Record 24 of Set 7 | paso de carrasco
# Processing Record 25 of Set 7 | torbay
# Processing Record 26 of Set 7 | jardim
# Processing Record 27 of Set 7 | goroka
# Processing Record 28 of Set 7 | wajid
# Processing Record 29 of Set 7 | karasjok
# Processing Record 30 of Set 7 | castro
# Processing Record 31 of Set 7 | guerrero negro
# Processing Record 32 of Set 7 | nouadhibou
# Processing Record 33 of Set 7 | sri aman
# Processing Record 34 of Set 7 | okha
# Processing Record 35 of Set 7 | cabra
# Processing Record 36 of Set 7 | lompoc
# Processing Record 37 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 7 | sungaipenuh
# Processing Record 39 of Set 7 | mansa
# Processing Record 40 of Set 7 | kuusankoski
# Processing Record 41 of Set 7 | phan thiet
# Processing Record 42 of Set 7 | pangody
# Processing Record 43 of Set 7 | ramhormoz
# Processing Record 44 of Set 7 | pisco
# Processing Record 45 of Set 7 | karratha
# Processing Record 46 of Set 7 | matara
# Processing Record 47 of Set 7 | jackson
# Processing Record 48 of Set 7 | sangar
# Processing Record 49 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 7 | cumra
# Processing Record 1 of Set 8 | comodoro rivadavia
# Processing Record 2 of Set 8 | havoysund
# Processing Record 3 of Set 8 | poum
# Processing Record 4 of Set 8 | myaundzha
# Processing Record 5 of Set 8 | grants pass
# Processing Record 6 of Set 8 | yangjiang
# Processing Record 7 of Set 8 | newport
# Processing Record 8 of Set 8 | panzhihua
# Processing Record 9 of Set 8 | fairbanks
# Processing Record 10 of Set 8 | guane
# Processing Record 11 of Set 8 | deder
# Processing Record 12 of Set 8 | xuddur
# Processing Record 13 of Set 8 | ugoofaaru
# Processing Record 14 of Set 8 | zheleznodorozhnyy
# Processing Record 15 of Set 8 | suleja
# Processing Record 16 of Set 8 | ban bung
# Processing Record 17 of Set 8 | mount isa
# Processing Record 18 of Set 8 | casalmaggiore
# Processing Record 19 of Set 8 | pachino
# Processing Record 20 of Set 8 | lorengau
# Processing Record 21 of Set 8 | bantry
# Processing Record 22 of Set 8 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 8 | joshimath
# Processing Record 24 of Set 8 | moranbah
# Processing Record 25 of Set 8 | omsukchan
# Processing Record 26 of Set 8 | saint stephen
# Processing Record 27 of Set 8 | lavrentiya
# Processing Record 28 of Set 8 | sistranda
# Processing Record 29 of Set 8 | cedar rapids
# Processing Record 30 of Set 8 | cardston
# Processing Record 31 of Set 8 | kathmandu
# Processing Record 32 of Set 8 | chabahar
# Processing Record 33 of Set 8 | changping
# Processing Record 34 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 35 of Set 8 | hosakote
# Processing Record 36 of Set 8 | kuytun
# Processing Record 37 of Set 8 | agidel
# Processing Record 38 of Set 8 | tiznit
# Processing Record 39 of Set 8 | nabire
# Processing Record 40 of Set 8 | najran
# Processing Record 41 of Set 8 | klaksvik
# Processing Record 42 of Set 8 | katsuura
# Processing Record 43 of Set 8 | zhigansk
# Processing Record 44 of Set 8 | sao raimundo nonato
# Processing Record 45 of Set 8 | dudinka
# Processing Record 46 of Set 8 | quang ngai
# Processing Record 47 of Set 8 | boende
# Processing Record 48 of Set 8 | camacari
# Processing Record 49 of Set 8 | snyder
# Processing Record 50 of Set 8 | rach gia
# Processing Record 1 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 9 | inhambane
# Processing Record 3 of Set 9 | half moon bay
# Processing Record 4 of Set 9 | bilma
# Processing Record 5 of Set 9 | vestmannaeyjar
# Processing Record 6 of Set 9 | mafinga
# Processing Record 7 of Set 9 | gigmoto
# Processing Record 8 of Set 9 | anaconda
# Processing Record 9 of Set 9 | nuuk
# Processing Record 10 of Set 9 | kalianget
# Processing Record 11 of Set 9 | kushmurun
# Processing Record 12 of Set 9 | bud
# Processing Record 13 of Set 9 | fiumicino
# Processing Record 14 of Set 9 | kamaishi
# Processing Record 15 of Set 9 | le vauclin
# Processing Record 16 of Set 9 | ewa beach
# Processing Record 17 of Set 9 | erzurum
# Processing Record 18 of Set 9 | fort portal
# Processing Record 19 of Set 9 | bukachacha
# Processing Record 20 of Set 9 | san vicente
# Processing Record 21 of Set 9 | marrakesh
# Processing Record 22 of Set 9 | ulaangom
# Processing Record 23 of Set 9 | sinnamary
# Processing Record 24 of Set 9 | buraydah
# Processing Record 25 of Set 9 | camopi
# Processing Record 26 of Set 9 | hambantota
# Processing Record 27 of Set 9 | caraquet
# Processing Record 28 of Set 9 | miri
# Processing Record 29 of Set 9 | tuatapere
# Processing Record 30 of Set 9 | catuday
# Processing Record 31 of Set 9 | kargopol
# Processing Record 32 of Set 9 | luanda
# Processing Record 33 of Set 9 | bereda
# Processing Record 34 of Set 9 | kodinsk
# Processing Record 35 of Set 9 | yei
# Processing Record 36 of Set 9 | berlevag
# Processing Record 37 of Set 9 | creel
# Processing Record 38 of Set 9 | langsa
# Processing Record 39 of Set 9 | iranshahr
# Processing Record 40 of Set 9 | lishui
# Processing Record 41 of Set 9 | qui nhon
# Processing Record 42 of Set 9 | obo
# Processing Record 43 of Set 9 | sao gabriel da cachoeira
# Processing Record 44 of Set 9 | ostersund
# Processing Record 45 of Set 9 | novaya igirma
# Processing Record 46 of Set 9 | thessalon
# Processing Record 47 of Set 9 | mustafakemalpasa
# Processing Record 48 of Set 9 | vaitape
# Processing Record 49 of Set 9 | bonthe
# Processing Record 50 of Set 9 | yulara
# Processing Record 1 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 2 of Set 10 | olga
# Processing Record 3 of Set 10 | camrose
# Processing Record 4 of Set 10 | tobermory
# Processing Record 5 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 10 | cap-aux-meules
# Processing Record 7 of Set 10 | saint-augustin
# Processing Record 8 of Set 10 | sibu
# Processing Record 9 of Set 10 | luderitz
# Processing Record 10 of Set 10 | luau
# Processing Record 11 of Set 10 | barabai
# Processing Record 12 of Set 10 | port hawkesbury
# Processing Record 13 of Set 10 | araouane
# Processing Record 14 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 10 | neuruppin
# Processing Record 16 of Set 10 | batyrevo
# Processing Record 17 of Set 10 | paamiut
# Processing Record 18 of Set 10 | harper
# Processing Record 19 of Set 10 | hamilton
# Processing Record 20 of Set 10 | perigueux
# Processing Record 21 of Set 10 | burica
# City not found. Skipping...
# Processing Record 22 of Set 10 | dangriga
# Processing Record 23 of Set 10 | nestorion
# City not found. Skipping...
# Processing Record 24 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 25 of Set 10 | catalao
# Processing Record 26 of Set 10 | noumea
# Processing Record 27 of Set 10 | auki
# Processing Record 28 of Set 10 | aksarka
# Processing Record 29 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 10 | kieta
# Processing Record 32 of Set 10 | altay
# Processing Record 33 of Set 10 | ponta delgada
# Processing Record 34 of Set 10 | wagar
# Processing Record 35 of Set 10 | helmstedt
# Processing Record 36 of Set 10 | siniscola
# Processing Record 37 of Set 10 | caravelas
# Processing Record 38 of Set 10 | coffs harbour
# Processing Record 39 of Set 10 | guanica
# Processing Record 40 of Set 10 | great yarmouth
# Processing Record 41 of Set 10 | kloulklubed
# Processing Record 42 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 10 | minas
# Processing Record 44 of Set 10 | rio gallegos
# Processing Record 45 of Set 10 | palkaka
# City not found. Skipping...
# Processing Record 46 of Set 10 | fukue
# Processing Record 47 of Set 10 | sokolka
# Processing Record 48 of Set 10 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 49 of Set 10 | baiyin
# Processing Record 50 of Set 10 | voskresenskoye
# Processing Record 1 of Set 11 | dali
# Processing Record 2 of Set 11 | nyakahanga
# Processing Record 3 of Set 11 | narsaq
# Processing Record 4 of Set 11 | liyang
# Processing Record 5 of Set 11 | vicuna
# Processing Record 6 of Set 11 | igrim
# Processing Record 7 of Set 11 | charters towers
# Processing Record 8 of Set 11 | nesna
# Processing Record 9 of Set 11 | trairi
# Processing Record 10 of Set 11 | manacapuru
# Processing Record 11 of Set 11 | mhango
# Processing Record 12 of Set 11 | kavieng
# Processing Record 13 of Set 11 | ongandjera
# Processing Record 14 of Set 11 | sodertalje
# City not found. Skipping...
# Processing Record 15 of Set 11 | sijunjung
# Processing Record 16 of Set 11 | youghal
# Processing Record 17 of Set 11 | ciudad guayana
# Processing Record 18 of Set 11 | lubango
# Processing Record 19 of Set 11 | loiza
# Processing Record 20 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 11 | nefteyugansk
# Processing Record 22 of Set 11 | san quintin
# Processing Record 23 of Set 11 | iberia
# Processing Record 24 of Set 11 | padang
# Processing Record 25 of Set 11 | sechura
# Processing Record 26 of Set 11 | santa maria
# Processing Record 27 of Set 11 | north bend
# Processing Record 28 of Set 11 | opuwo
# Processing Record 29 of Set 11 | mandalgovi
# Processing Record 30 of Set 11 | roald
# Processing Record 31 of Set 11 | vigrestad
# Processing Record 32 of Set 11 | kawalu
# Processing Record 33 of Set 11 | chernyshkovskiy
# Processing Record 34 of Set 11 | ambanja
# Processing Record 35 of Set 11 | pevek
# Processing Record 36 of Set 11 | guangyuan
# Processing Record 37 of Set 11 | mazamari
# Processing Record 38 of Set 11 | kabo
# Processing Record 39 of Set 11 | tautira
# Processing Record 40 of Set 11 | svetlogorsk
# Processing Record 41 of Set 11 | wanning
# Processing Record 42 of Set 11 | motozintla
# Processing Record 43 of Set 11 | vysokogornyy
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | labuhan
# Processing Record 46 of Set 11 | mikhaylovka
# Processing Record 47 of Set 11 | anadyr
# Processing Record 48 of Set 11 | biltine
# Processing Record 49 of Set 11 | bati
# Processing Record 50 of Set 11 | abhar
# Processing Record 1 of Set 12 | yelizovo
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | beloha
# Processing Record 4 of Set 12 | komsomolskiy
# Processing Record 5 of Set 12 | rafaela
# Processing Record 6 of Set 12 | challans
# Processing Record 7 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 12 | mogok
# Processing Record 9 of Set 12 | porto novo
# Processing Record 10 of Set 12 | menomonie
# Processing Record 11 of Set 12 | kathu
# Processing Record 12 of Set 12 | scarborough
# Processing Record 13 of Set 12 | mareeba
# Processing Record 14 of Set 12 | glace bay
# Processing Record 15 of Set 12 | strezhevoy
# Processing Record 16 of Set 12 | gwadar
# Processing Record 17 of Set 12 | lethem
# Processing Record 18 of Set 12 | calabozo
# Processing Record 19 of Set 12 | kungurtug
# Processing Record 20 of Set 12 | jimenez
# Processing Record 21 of Set 12 | larsnes
# Processing Record 22 of Set 12 | hoi an
# Processing Record 23 of Set 12 | pushkino
# Processing Record 24 of Set 12 | gamboula
# Processing Record 25 of Set 12 | bonfim
# Processing Record 26 of Set 12 | mehamn
# Processing Record 27 of Set 12 | alamos
# Processing Record 28 of Set 12 | kirakira
# Processing Record 29 of Set 12 | puntarenas
# Processing Record 30 of Set 12 | kpandu
# Processing Record 31 of Set 12 | bagotville
# Processing Record 32 of Set 12 | cozumel
# Processing Record 33 of Set 12 | adrar
# Processing Record 34 of Set 12 | aykhal
# Processing Record 35 of Set 12 | dukat
# Processing Record 36 of Set 12 | cantanhede
# Processing Record 37 of Set 12 | murgab
# Processing Record 38 of Set 12 | kindu
# Processing Record 39 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 12 | la orilla
# Processing Record 42 of Set 12 | hirara
# Processing Record 43 of Set 12 | ruthin
# Processing Record 44 of Set 12 | leh
# Processing Record 45 of Set 12 | gunnedah
# Processing Record 46 of Set 12 | harur
# Processing Record 47 of Set 12 | turayf
# Processing Record 48 of Set 12 | alzamay
# Processing Record 49 of Set 12 | basoko
# Processing Record 50 of Set 12 | hays
# Processing Record 1 of Set 13 | santa rosa
# Processing Record 2 of Set 13 | jining
# Processing Record 3 of Set 13 | warrnambool
# Processing Record 4 of Set 13 | nyurba
# Processing Record 5 of Set 13 | namibe
# Processing Record 6 of Set 13 | dongning
# Processing Record 7 of Set 13 | tulsipur
# Processing Record 8 of Set 13 | milkovo
# Processing Record 9 of Set 13 | san felipe
# Processing Record 10 of Set 13 | dongying
# Processing Record 11 of Set 13 | meiganga
# Processing Record 12 of Set 13 | trincomalee
# Processing Record 13 of Set 13 | port-gentil
# Processing Record 14 of Set 13 | kupino
# Processing Record 15 of Set 13 | fuxin
# Processing Record 16 of Set 13 | juba
# Processing Record 17 of Set 13 | atar
# Processing Record 18 of Set 13 | sumbe
# Processing Record 19 of Set 13 | egvekinot
# Processing Record 20 of Set 13 | bac giang
# Processing Record 21 of Set 13 | yar-sale
# Processing Record 22 of Set 13 | kuvandyk
# Processing Record 23 of Set 13 | souillac
# Processing Record 24 of Set 13 | doaba
# Processing Record 25 of Set 13 | buchanan
# Processing Record 26 of Set 13 | yaan
# Processing Record 27 of Set 13 | fukuma
# Processing Record 28 of Set 13 | zambezi
# Processing Record 29 of Set 13 | cape coast
# Processing Record 30 of Set 13 | punta alta
# Processing Record 31 of Set 13 | mogadishu
# Processing Record 32 of Set 13 | bardiyah
# Processing Record 33 of Set 13 | terrace bay
# Processing Record 34 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 13 | nha trang
# Processing Record 36 of Set 13 | alexandria
# Processing Record 37 of Set 13 | morehead
# Processing Record 38 of Set 13 | dutse
# Processing Record 39 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 40 of Set 13 | sarangani
# Processing Record 41 of Set 13 | brae
# Processing Record 42 of Set 13 | necochea
# Processing Record 43 of Set 13 | itabira
# Processing Record 44 of Set 13 | mayskiy
# Processing Record 45 of Set 13 | monrovia
# Processing Record 46 of Set 13 | camacupa
# Processing Record 47 of Set 13 | zorritos
# Processing Record 48 of Set 13 | samandag
# Processing Record 49 of Set 13 | jacqueville
# Processing Record 50 of Set 13 | port blair
# Processing Record 1 of Set 14 | salinas
# Processing Record 2 of Set 14 | timrat
# Processing Record 3 of Set 14 | coari
# Processing Record 4 of Set 14 | marquette
# Processing Record 5 of Set 14 | fougamou
# Processing Record 6 of Set 14 | litovko
# Processing Record 7 of Set 14 | flinders
# Processing Record 8 of Set 14 | dryden
# Processing Record 9 of Set 14 | roman
# Processing Record 10 of Set 14 | alofi
# Processing Record 11 of Set 14 | san mateo del mar
# Processing Record 12 of Set 14 | birin
# Processing Record 13 of Set 14 | ust-omchug
# Processing Record 14 of Set 14 | manuk mangkaw
# Processing Record 15 of Set 14 | katsina
# Processing Record 16 of Set 14 | troitskiy
# Processing Record 17 of Set 14 | bababe
# City not found. Skipping...
# Processing Record 18 of Set 14 | sao mateus
# Processing Record 19 of Set 14 | korla
# Processing Record 20 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 21 of Set 14 | ginda
# Processing Record 22 of Set 14 | paluan
# Processing Record 23 of Set 14 | wajima
# Processing Record 24 of Set 14 | koshurnikovo
# Processing Record 25 of Set 14 | bonavista
# Processing Record 26 of Set 14 | quatre cocos
# Processing Record 27 of Set 14 | mayumba
# Processing Record 28 of Set 14 | carutapera
# Processing Record 29 of Set 14 | angoche
# Processing Record 30 of Set 14 | charcas
# Processing Record 31 of Set 14 | thinadhoo
# Processing Record 32 of Set 14 | izhma
# Processing Record 33 of Set 14 | hoopstad
# Processing Record 34 of Set 14 | pulandian
# Processing Record 35 of Set 14 | jiuquan
# Processing Record 36 of Set 14 | waingapu
# Processing Record 37 of Set 14 | bremerton
# Processing Record 38 of Set 14 | alyangula
# Processing Record 39 of Set 14 | alghero
# Processing Record 40 of Set 14 | jiwani
# Processing Record 41 of Set 14 | tobias barreto
# Processing Record 42 of Set 14 | yongchang
# Processing Record 43 of Set 14 | fare
# Processing Record 44 of Set 14 | mitsamiouli
# Processing Record 45 of Set 14 | gao
# Processing Record 46 of Set 14 | lagunas
# Processing Record 47 of Set 14 | nayudupeta
# Processing Record 48 of Set 14 | polewali
# Processing Record 49 of Set 14 | devonport
# Processing Record 50 of Set 14 | camocim
# Processing Record 1 of Set 15 | snezhnogorsk
# Processing Record 2 of Set 15 | changqing
# Processing Record 3 of Set 15 | mananjary
# Processing Record 4 of Set 15 | micheweni
# Processing Record 5 of Set 15 | kapoeta
# Processing Record 6 of Set 15 | alice springs
# Processing Record 7 of Set 15 | birao
# Processing Record 8 of Set 15 | broken hill
# Processing Record 9 of Set 15 | shingu
# Processing Record 10 of Set 15 | bozova
# Processing Record 11 of Set 15 | hun
# Processing Record 12 of Set 15 | moerai
# Processing Record 13 of Set 15 | beira
# Processing Record 14 of Set 15 | ures
# Processing Record 15 of Set 15 | tolmin
# Processing Record 16 of Set 15 | termiz
# Processing Record 17 of Set 15 | okhotsk
# Processing Record 18 of Set 15 | phangnga
# Processing Record 19 of Set 15 | chippewa falls
# Processing Record 20 of Set 15 | korcula
# Processing Record 21 of Set 15 | elko
# Processing Record 22 of Set 15 | dunedin
# Processing Record 23 of Set 15 | sabzevar
# Processing Record 24 of Set 15 | ipixuna
# Processing Record 25 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 26 of Set 15 | byron bay
# Processing Record 27 of Set 15 | talah
# City not found. Skipping...
# Processing Record 28 of Set 15 | tateyama
# Processing Record 29 of Set 15 | mentok
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vostok  46.4856  135.8833      3.63        96          60
# 1        Qaanaaq  77.4840  -69.3632    -13.22        78         100
# 2   Punta Arenas -53.1500  -70.9167     44.62        73          56
# 3  Srednekolymsk  67.4500  153.6833    -11.83        99         100
# 4          Lagoa  39.0500  -27.9833     58.75        86         100
# 5      Hachinohe  40.5000  141.5000     31.87        84          53
# 6         Touros  -5.1989  -35.4608     85.75        64          99
# 7  Pacific Grove  36.6177 -121.9166     50.67        92          75
# 8     Georgetown   5.4112  100.3354     76.98        94          40
# 9        Sorland  67.6670   12.6934     40.86        93          75
#
#    Wind Speed Country           Current Description
# 0        3.36      RU                 broken clouds
# 1       10.94      GL               overcast clouds
# 2       21.14      CL                    light rain
# 3        3.29      RU               overcast clouds
# 4       33.15      PT               overcast clouds
# 5        4.43      JP                 broken clouds
# 6       11.01      BR               overcast clouds
# 7        1.01      US                          haze
# 8        5.75      MY  thunderstorm with light rain
# 9       10.36      NO                    light rain

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", 
                             "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]


city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vostok      RU  46.4856  135.8833      3.63        96          60
# 1        Qaanaaq      GL  77.4840  -69.3632    -13.22        78         100
# 2   Punta Arenas      CL -53.1500  -70.9167     44.62        73          56
# 3  Srednekolymsk      RU  67.4500  153.6833    -11.83        99         100
# 4          Lagoa      PT  39.0500  -27.9833     58.75        86         100
#
#    Wind Speed Current Description
# 0        3.36       broken clouds
# 1       10.94     overcast clouds
# 2       21.14          light rain
# 3        3.29     overcast clouds
# 4       33.15     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
